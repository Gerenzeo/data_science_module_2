# %% [markdown]
# <a href="https://colab.research.google.com/github/Gerenzeo/data_science_module_2/blob/main/Hw2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8"
table_12 = pd.read_html(url)[12]

# %% [markdown]
# 1. Вивести перші рядки таблиці за допомогою методу head

# %%
print(table_12.head())
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %% [markdown]
# 2. Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
print(table_12.shape)
# Out:
# (28, 9)

# %% [markdown]
# 3. Замініть у таблиці значення "—" на значення NaN

# %%
table_12.replace("—", "NaN", inplace=True)
print(table_12)
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82  NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51  NaN
# ...

# %% [markdown]
# 4. Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
print(table_12.dtypes)
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %% [markdown]
# 5. Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
table_12.replace("NaN", 0, inplace=True)
print(table_12)
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126    0    0
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82    0
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51    0
# ...

# %% [markdown]
# 6. Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
print(table_12.isnull().sum() / len(table_12) * 100)
# Out:
# Регіон    0.000000
# 1950      7.142857
# 1960      3.571429
# 1970      3.571429
# 1990      0.000000
# 2000      0.000000
# 2012      0.000000
# 2014      0.000000
# 2019      0.000000
# dtype: float64

# %% [markdown]
# 7. Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
table_12.drop(table_12.index[-1], inplace=True)
print(table_12)
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126    0    0
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82    0
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51    0
# ...

# %% [markdown]
# 8. Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
table_12.fillna(table_12.mean(numeric_only=True), inplace=True)
print(table_12)
# Out:
#                Регіон    1950        1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.00  206.000000  160.0   130    73   126    0    0
# 1           Вінницька  224.00  192.000000  142.0   124    84   112  109   76
# 2           Волинська  247.00  250.000000  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.00  204.000000  151.0   123    71   112  111   71
# 4            Донецька  271.00  214.000000  140.0   109    61    98   82    0
# 5         Житомирська  261.00  223.000000  159.0   129    89   122  120   79
# 6        Закарпатська  314.00  273.000000  207.0   168   115   151  146  104
# 7          Запорізька  219.00  197.000000  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.00  248.000000  182.0   155   103   124  122   88
# 9            Київська  204.00  189.000000  156.0   123    73   122  121   80
# 10     Кіровоградська  216.00  171.000000  145.0   126    79   110  108   68
# ...

# %% [markdown]
# 9. Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні

# %%
table_12["2019"] = pd.to_numeric(table_12["2019"], errors="coerce")
average_2019 = table_12["2019"].mean()

print(table_12[table_12['2019'] > average_2019])
# Out:
#                Регіон    1950   1960   1970  1990  2000  2012 2014  2019
# 1           Вінницька  224.00  192.0  142.0   124    84   112  109    76
# 2           Волинська  247.00  250.0  179.0   153   112   148  141   101
# 3    Дніпропетровська  204.00  204.0  151.0   123    71   112  111    71
# 5         Житомирська  261.00  223.0  159.0   129    89   122  120    79
# 6        Закарпатська  314.00  273.0  207.0   168   115   151  146   104
# 8   Івано-Франківська  243.00  248.0  182.0   155   103   124  122    88
# 9            Київська  204.00  189.0  156.0   123    73   122  121    80
# 12          Львівська  234.00  240.0  171.0   140    91   119  119    87
# 13       Миколаївська  211.00  194.0  155.0   137    80   115  112    71
# 14            Одеська  241.00  192.0  148.0   126    80   127  123    88
# 16         Рівненська  269.00  267.0  193.0   158   118   159  148   107
# 18      Тернопільська  213.00  216.0  157.0   142    92   113  109    76
# ...

# %% [markdown]
# 10. У якому регіоні була найвища народжуваність у 2014 році?

# %%
table_12["2014"] = pd.to_numeric(table_12["2014"], errors="coerce")
print(table_12.loc[table_12["2014"].idxmax(), "Регіон"])
# Out:
# Рівненська

# %% [markdown]
# 11. Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
import matplotlib.pyplot as plt

# %%
data_2019 = table_12[["Регіон", "2019"]]
data_2019 = data_2019.dropna()
data_2019["2019"] = pd.to_numeric(data_2019["2019"], errors="coerce")

sort_data = data_2019.sort_values('2019', ascending=False)

plt.figure(figsize=(12, 8))
plt.bar(sort_data["Регіон"], sort_data['2019'], color='navy')
plt.title("Народжуваність по регіонах в 2019 році")
plt.xlabel("Регіон")
plt.ylabel("Кількість народжень в 2019 році")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Візуалізація**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Графік 1

# %%
plt.figure(figsize=(10, 6))
df_2019 = table_12[['Регіон', '2019']].dropna()
plt.bar(df_2019['Регіон'], df_2019['2019'], color='skyblue')
plt.xlabel('Регіон')
plt.ylabel('Населення у 2019 році')
plt.title('Розподіл населення за регіонами у 2019 році')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Графік 2

# %%
plt.figure(figsize=(10, 6))
df_change = table_12[['Регіон', '1950', '2019']].dropna()
df_change['Change'] = df_change['2019'].astype(float) - df_change['1950'].astype(float)
plt.bar(df_change['Регіон'], df_change['Change'], color='lightgreen')
plt.xlabel('Регіон')
plt.ylabel('Зміна населення (2019 - 1950)')
plt.title('Зміна населення за регіонами з 1950 по 2019 рік')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Графік 3

# %%
plt.figure(figsize=(12, 8))
df_pyramid = table_12[['Регіон', '1950']].dropna()
plt.barh(df_pyramid['Регіон'], df_pyramid['1950'], color='skyblue')
plt.xlabel('Населення')
plt.ylabel('Регіон')
plt.title('Піраміда населення за регіонами у 1950 році')
plt.show()
